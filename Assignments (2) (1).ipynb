# %%
#Consider the string given below and answer the following questions
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"

# %% [markdown]
# **bold text**####  Calculate the number of characters in the string
#
# -  193
# -  200
# -  300
# -  500

# %%
# Type your code here
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"
count = len(string)
print(count)
# Out:
# 193

# %% [markdown]
# #### Count the number of occurences of 'a' in the string
#
# -  1
# -  2
# -  10
# -  5

# %%
# Type your code here
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"
count_a = string.count('a')
print(count_a)
# Out:
# 2

# %% [markdown]
# #### Identify whether the string starts with 'if'.
#
# -  True
# -  False

# %%
# Type your code here
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"
result = string.startswith("if")
print(result)
# Out:
# False

# %% [markdown]
# #### Return the substring starting at index 63 and ending at index 88  [Both the indexes are inclusive]
#
# -  'OQYWFClFhFGA'
# -  'mCfgDYqbaBHAUvIWhMnvwZnEMV'
# -  'IWYwGKpmZhnJiyzTslSIhSwv'
# -  'JMEphzmifTkyqOMNpnOtXZ'

# %%
# Type your code here
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"
substring = string[63:89]  # End index should be 89 to include 88
print(substring)
# Out:
# mCfgDYqbaBHAUvIWhMnvwZnEMV

# %% [markdown]
# #### Identify the character at index 45
#
# -  a
# -  b
# -  z
# -  x

# %%
# Type your code here
string = "OQYWFClFhFGAvIWYwGKpmZhnJiyzTslSIhSwvOsqJMEphzmifTkyqOMNpnOtXZxmCfgDYqbaBHAUvIWhMnvwZnEMVDvmEfLrDoQnAZgQEgXQVnmSYkfedpAdhrtpOgORpYLRZYGWdhWYuqQssCUXtTzKRDAhpjUheOzUroZNzWFtZOVwIapzUYtbSbjYNErzQ"
char_at_45 = string[45]  # Accessing the character at index 45
print(char_at_45)
# Out:
# z
